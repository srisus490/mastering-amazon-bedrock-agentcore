# %% [markdown]
# # Notebook 03: Gateway Integration
#
# ## Learning Objectives
# - Create AgentCore Gateway with external API integrations
# - Configure OpenAPI 3.0 specifications for travel APIs
# - Set up OAuth authentication with Cognito
# - Test MCP tool calling with real APIs
# - Integrate Gateway tools into travel agent
#
# ## Prerequisites
# - Completed Notebook 02 (Runtime Setup)
# - All 4 API keys configured
# - Travel agent deployed to AgentCore Runtime

# %% [markdown]
# ## Step 1: Connect to your AWS environment

# %%
import os

os.environ['AWS_REGION'] = 'us-east-1'

# APPROACH A: Use credentials
os.environ['AWS_ACCESS_KEY_ID'] = 'YOUR_AWS_ACCESS_KEY_ID'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'YOUR_AWS_SECRET_ACCESS_KEY'
# os.environ['AWS_SESSION_TOKEN'] = "your_session_token"

# APPROACH B: Use AWS SSO profile
#os.environ['AWS_PROFILE'] = 'your_profile'
# Remove any existing credential env vars to force profile usage
#for key in ['AWS_ACCESS_KEY_ID', 'AWS_SECRET_ACCESS_KEY', 'AWS_SESSION_TOKEN']:
#    os.environ.pop(key, None)

os.environ['AWS_REGION'] = 'us-east-1'

print("✅ AWS Profile set. Please restart kernel and run all cells.")
# Out:
# ✅ AWS Profile set. Please restart kernel and run all cells.

# %%
import os
import json
from dotenv import load_dotenv
from bedrock_agentcore_starter_toolkit.operations.gateway.client import GatewayClient

# Load environment variables
load_dotenv()

print("✅ Gateway integration imports successful")
# Out:
# ✅ Gateway integration imports successful

# %%
# Configure 3rd Party APIs
os.environ['AVIATIONSTACK_API_KEY'] = "91a13edd91c45258407b5441a7fe4bf9"
os.environ['OPENWEATHERMAP_API_KEY'] = "d50394365452bf0b5a7fbd749d4b1d17"
os.environ['EXCHANGERATE_API_KEY'] = "1876e28e1d152b5b155ec14e"

# %% [markdown]
# ## Step 2: Validate API Keys

# %%
# Validate all required API keys
api_keys = {
    "AVIATIONSTACK_API_KEY": os.getenv("AVIATIONSTACK_API_KEY"),
    "OPENWEATHERMAP_API_KEY": os.getenv("OPENWEATHERMAP_API_KEY"),
    "EXCHANGERATE_API_KEY": os.getenv("EXCHANGERATE_API_KEY")
}

print("🔑 API Key Validation:")
for key_name, key_value in api_keys.items():
    if key_value:
        print(f"✅ {key_name}: {'*' * 8}{key_value[-4:]}")
    else:
        print(f"❌ {key_name}: Not configured")

missing_keys = [k for k, v in api_keys.items() if not v]
if missing_keys:
    print(f"\n⚠️ Missing API keys: {', '.join(missing_keys)}")
    print("Please configure these before proceeding.")
    raise ValueError("Missing required API keys")
else:
    print("\n✅ All API keys configured!")
# Out:
# 🔑 API Key Validation:
# ✅ AVIATIONSTACK_API_KEY: ********4bf9
# ✅ OPENWEATHERMAP_API_KEY: ********1d17
# ✅ EXCHANGERATE_API_KEY: ********c14e
#
# ✅ All API keys configured!

# %% [markdown]
# ## Step 3: Review OpenAPI Specifications

# %%
# Load and display OpenAPI specifications
def load_openapi_spec(filename):
    """Load OpenAPI specification from file"""
    with open(f"../backend/gateway/openapi_specs/{filename}", "r") as f:
        return json.load(f)

# Load all specifications
specs = {
    "Aviationstack (Flights)": load_openapi_spec("aviationstack.json"),
    "OpenWeatherMap (Weather)": load_openapi_spec("openweathermap.json"),
    "ExchangeRate-API (Currency)": load_openapi_spec("exchangerate.json")
}

print("📋 OpenAPI Specifications Overview:")
print("=" * 50)

for api_name, spec in specs.items():
    print(f"\n🔧 {api_name}")
    print(f"   Base URL: {spec['servers'][0]['url']}")
    print(f"   Operations:")
    
    for path, methods in spec['paths'].items():
        for method, details in methods.items():
            if 'operationId' in details:
                print(f"     - {details['operationId']}: {details['summary']}")
# Out:
# 📋 OpenAPI Specifications Overview:
# ==================================================
#
# 🔧 Aviationstack (Flights)
#    Base URL: https://api.aviationstack.com/v1
#    Operations:
#      - getFlights: Flights
#
# 🔧 OpenWeatherMap (Weather)
#    Base URL: https://api.openweathermap.org/data/2.5
#    Operations:
#      - getCurrentWeather: Get current weather
#      - getWeatherForecast: Get weather forecast
#
# 🔧 ExchangeRate-API (Currency)
#    Base URL: https://v6.exchangerate-api.com/v6
#    Operations:
#      - getExchangeRates: Get latest exchange rates
#      - convertCurrency: Convert between currencies

# %% [markdown]
# ## Step 4: Create AgentCore Gateway

# %%
# Initialize Gateway client
REGION = "us-east-1"
GATEWAY_NAME = "TravelMateGateway"

print(f"🚀 Creating AgentCore Gateway: {GATEWAY_NAME}")
print(f"Region: {REGION}")

client = GatewayClient(region_name=REGION)
print("✅ Gateway client initialized")
# Out:
# 🚀 Creating AgentCore Gateway: TravelMateGateway
# Region: us-east-1
# ✅ Gateway client initialized

# %%
# Set up OAuth with Cognito (EZ Auth)
import sys
sys.path.append('../backend')

from cognito_config import setup_cognito_oauth

print("🔐 Setting up OAuth with Cognito...")
cognito_result = setup_cognito_oauth(client, GATEWAY_NAME)

print("✅ OAuth configuration complete")
print(f"Client ID: {cognito_result['client_info']['client_id']}")
print(f"Scope: {cognito_result['client_info']['scope']}")
# Out:
# 🔐 Setting up OAuth with Cognito...
# ⚠️ Error loading Cognito config: Expecting value: line 1 column 1 (char 0)
# 2026-02-10 09:24:45,730 - bedrock_agentcore.gateway - INFO - Starting EZ Auth setup: Creating Cognito resources...
# 🔐 Creating new Cognito OAuth configuration...
# 2026-02-10 09:24:48,280 - bedrock_agentcore.gateway - INFO -   ✓ Created User Pool: us-east-1_kMggiIpM4
# 2026-02-10 09:24:49,253 - bedrock_agentcore.gateway - INFO -   ✓ Created domain: agentcore-c1478952
# 2026-02-10 09:24:49,253 - bedrock_agentcore.gateway - INFO -   ⏳ Waiting for domain to be available...
# 2026-02-10 09:24:50,621 - bedrock_agentcore.gateway - INFO -   ✓ Domain is active
# 2026-02-10 09:24:51,166 - bedrock_agentcore.gateway - INFO -   ✓ Created resource server: TravelMateGateway
# 2026-02-10 09:24:51,701 - bedrock_agentcore.gateway - INFO -   ✓ Created client: 42g73g97d8cf2us2ebuf3hhu0k
# 2026-02-10 09:24:51,701 - bedrock_agentcore.gateway - INFO -   ⏳ Waiting for DNS propagation of domain: agentcore-c1478952.auth.us-east-1.amazoncognito.com
# 2026-02-10 09:25:51,715 - bedrock_agentcore.gateway - INFO - ✓ EZ Auth setup complete!
# 💾 Cognito config saved to ../notebooks/environments/cognito_config.json
# 🔧 Enabling USER_PASSWORD_AUTH flow...
# ✅ USER_PASSWORD_AUTH flow enabled
# ✅ Enabled client_credentials OAuth flow
# ✅ OAuth configuration complete
# Client ID: 42g73g97d8cf2us2ebuf3hhu0k
# Scope: TravelMateGateway/invoke

# %%
import boto3

def activate_oauth(client_info):
    """Fix OAuth configuration for Cognito client"""
    cognito_client = boto3.client('cognito-idp', region_name='us-east-1')
    
    try:
        cognito_client.update_user_pool_client(
            UserPoolId=client_info['user_pool_id'],
            ClientId=client_info['client_id'],
            AllowedOAuthFlows=['client_credentials'],
            AllowedOAuthScopes=[client_info['scope']],
            AllowedOAuthFlowsUserPoolClient=True
        )
        print("✅ Fixed Cognito OAuth configuration")
    except Exception as e:
        print(f"❌ Failed to fix OAuth config: {e}")
        raise

# Apply the fix after cognito_result is created
activate_oauth(cognito_result['client_info'])
# Out:
# ✅ Fixed Cognito OAuth configuration

# %%
# Create or get existing Gateway
print(f"🏗️ Creating Gateway: {GATEWAY_NAME}...")

try:
    gateway = client.create_mcp_gateway(
        name=GATEWAY_NAME,
        role_arn=None,  # Auto-create
        authorizer_config=cognito_result['authorizer_config'],
        enable_semantic_search=True
    )
    print("✅ Gateway created successfully!")
except:
    print(f"⚠️ Gateway {GATEWAY_NAME} already exists, retrieving...")
    # Get existing gateway
    gateways = client.client.list_gateways()['items']
    gateway = next((g for g in gateways if g['name'] == GATEWAY_NAME), None)
    if gateway:
        gateway = client.client.get_gateway(gatewayIdentifier=gateway['gatewayId'])
        print("✅ Retrieved existing gateway")
    else:
        raise Exception(f"Gateway {GATEWAY_NAME} not found")

print(f"MCP Endpoint: {gateway['gatewayUrl']}")
print(f"Gateway ID: {gateway['gatewayId']}")
# Out:
# 2026-02-10 09:31:08,447 - bedrock_agentcore.gateway - INFO - Role not provided, creating an execution role to use
# 🏗️ Creating Gateway: TravelMateGateway...
# 2026-02-10 09:31:17,666 - bedrock_agentcore.gateway - INFO - ✓ Successfully created execution role for Gateway
# 2026-02-10 09:31:17,668 - bedrock_agentcore.gateway - INFO - Creating Gateway
# 2026-02-10 09:31:18,987 - bedrock_agentcore.gateway - INFO - ✓ Created Gateway: arn:aws:bedrock-agentcore:us-east-1:790402872574:gateway/travelmategateway-ufmin6tijj
# 2026-02-10 09:31:18,991 - bedrock_agentcore.gateway - INFO -   Gateway URL: https://travelmategateway-ufmin6tijj.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp
# 2026-02-10 09:31:18,993 - bedrock_agentcore.gateway - INFO -   Waiting for Gateway to be ready...
# 2026-02-10 09:31:21,968 - bedrock_agentcore.gateway - INFO -
# ✅Gateway is ready
# ✅ Gateway created successfully!
# MCP Endpoint: https://travelmategateway-ufmin6tijj.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp
# Gateway ID: travelmategateway-ufmin6tijj

# %% [markdown]
# ## Step 5: Add API Targets to Gateway

# %%
# Add Aviationstack target (Flight search)
print("✈️ Adding Aviationstack (Flight Search)...")

aviationstack_spec = specs["Aviationstack (Flights)"]
aviationstack_target = client.create_mcp_gateway_target(
    gateway=gateway,
    name="FlightSearch", 
    target_type="openApiSchema",
    target_payload={
        "inlinePayload": json.dumps(aviationstack_spec)
    },
    credentials={
        "api_key": api_keys["AVIATIONSTACK_API_KEY"],
        "credential_location": "QUERY_PARAMETER",
        "credential_parameter_name": "access_key"
    }
)

aviationstack_target_name = aviationstack_target['name']
print("✅ Aviationstack target added")
print(f"   Available tool: {aviationstack_target_name}___getFlights")
# Out:
# 2026-02-10 09:32:58,344 - bedrock_agentcore.gateway - INFO - Creating credential provider
# ✈️ Adding Aviationstack (Flight Search)...
# 2026-02-10 09:32:59,916 - bedrock_agentcore.gateway - INFO - ✓ Added credential provider successfully (ARN: arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/FlightSearch-ApiKey-938fcd7a)
# 2026-02-10 09:32:59,919 - bedrock_agentcore.gateway - INFO - Creating Target
# 2026-02-10 09:32:59,920 - bedrock_agentcore.gateway - INFO - {'gatewayIdentifier': 'travelmategateway-ufmin6tijj', 'name': 'FlightSearch', 'targetConfiguration': {'mcp': {'openApiSchema': {'inlinePayload': '{"openapi": "3.1.0", "info": {"title": "Aviationstack API", "description": "The Aviationstack API was built to provide a simple way of accessing global aviation data for real-time, historical flights, and future flights as well as allow customers to tap into an extensive data set of airline routes and other up-to-date aviation-related information. Requests to the REST API are made using a straightforward HTTP GET URL structure and responses are provided in lightweight JSON format.\\n", "contact": {"name": "Aviationstack Documentation"}, "version": "1.0.0"}, "servers": [{"url": "https://api.aviationstack.com/v1", "description": "Main Aviationstack API server"}], "security": [{"AviationstackApiKey": []}], "paths": {"/flights": {"get": {"summary": "Flights", "description": "The Flights endpoint is capable of tracking flights and retrieving flight status information in real-time. In order to look up real-time information about one or multiple flights, you can use the API\'s Flights endpoint together with optional parameters to filter your result set.\\n", "operationId": "getFlights", "parameters": [{"$ref": "#/components/parameters/limit"}, {"$ref": "#/components/parameters/offset"}, {"$ref": "#/components/parameters/flight_date"}, {"$ref": "#/components/parameters/flight_status"}, {"$ref": "#/components/parameters/dep_iata"}, {"$ref": "#/components/parameters/arr_iata"}, {"$ref": "#/components/parameters/dep_icao"}, {"$ref": "#/components/parameters/arr_icao"}, {"$ref": "#/components/parameters/airline_name"}, {"$ref": "#/components/parameters/airline_iata"}, {"$ref": "#/components/parameters/airline_icao"}, {"$ref": "#/components/parameters/flight_number"}, {"$ref": "#/components/parameters/flight_iata"}, {"$ref": "#/components/parameters/flight_icao"}, {"$ref": "#/components/parameters/min_delay_dep"}, {"$ref": "#/components/parameters/min_delay_arr"}, {"$ref": "#/components/parameters/max_delay_dep"}, {"$ref": "#/components/parameters/max_delay_arr"}, {"$ref": "#/components/parameters/arr_scheduled_time_arr"}, {"$ref": "#/components/parameters/dep_scheduled_time_dep"}, {"$ref": "#/components/parameters/callback"}], "responses": {"200": {"description": "Flight list (pagination + flights array)", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/FlightListResponse"}}}}, "4XX": {"description": "Client error (see ErrorResponse)", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/ErrorResponse"}}}}}}}}, "components": {"schemas": {"Pagination": {"type": "object", "properties": {"limit": {"type": "integer", "description": "Requested limit per page.", "example": 100}, "offset": {"type": "integer", "description": "Requested offset.", "example": 0}, "count": {"type": "integer", "description": "Number of returned results on this page.", "example": 100}, "total": {"type": "integer", "description": "Total number of results matching the query.", "example": 1669022}}}, "DepartureArrivalBase": {"type": "object", "properties": {"airport": {"type": "string", "description": "Airport name"}, "timezone": {"type": "string", "description": "IANA timezone string"}, "iata": {"type": "string", "description": "IATA code"}, "icao": {"type": "string", "description": "ICAO code"}, "terminal": {"type": "string", "description": "Terminal (if available)"}, "gate": {"type": "string", "description": "Gate number (if available)"}, "delay": {"type": "integer", "description": "Delay in minutes"}, "scheduled": {"type": "string", "format": "date-time", "description": "Scheduled time"}, "estimated": {"type": "string", "format": "date-time", "description": "Estimated time (if available)"}, "actual": {"type": "string", "format": "date-time", "description": "Actual time (if available)"}, "estimated_runway": {"type": "st ...
# ---------------------------------------------------------------------------
# ConflictException                         Traceback (most recent call last)
# Cell In[17], line 5
#       2 print("✈️ Adding Aviationstack (Flight Search)...")
#       4 aviationstack_spec = specs["Aviationstack (Flights)"]
# ----> 5 aviationstack_target = client.create_mcp_gateway_target(
#       6     gateway=gateway,
#       7     name="FlightSearch",
#       8     target_type="openApiSchema",
#       9     target_payload={
#      10         "inlinePayload": json.dumps(aviationstack_spec)
#      11     },
#      12     credentials={
#      13         "api_key": api_keys["AVIATIONSTACK_API_KEY"],
#      14         "credential_location": "QUERY_PARAMETER",
#      15         "credential_parameter_name": "access_key"
#      16     }
#      17 )
#      19 aviationstack_target_name = aviationstack_target['name']
#      20 print("✅ Aviationstack target added")
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\bedrock_agentcore_starter_toolkit\operations\gateway\client.py:164, in GatewayClient.create_mcp_gateway_target(self, gateway, name, target_type, target_payload, credentials)
#     162 self.logger.info(create_request)
#     163 self.logger.debug("Creating target with params: %s", json.dumps(create_request, indent=2))
# --> 164 target = self.client.create_gateway_target(**create_request)
#     165 self.logger.info("✓ Added target successfully (ID: %s)", target["targetId"])
#     166 self.logger.info("  Waiting for target to be ready...")
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ConflictException: An error occurred (ConflictException) when calling the CreateGatewayTarget operation: A target with name 'FlightSearch' already exists in this gateway

# %%
# Add OpenWeatherMap target (Weather)
print("🌤️ Adding OpenWeatherMap (Weather)...")

weather_spec = specs["OpenWeatherMap (Weather)"]
weather_target = client.create_mcp_gateway_target(
    gateway=gateway,
    name="WeatherSearch",
    target_type="openApiSchema",
    target_payload={
        "inlinePayload": json.dumps(weather_spec)
    },
    credentials={
        "api_key": api_keys["OPENWEATHERMAP_API_KEY"],
        "credential_location": "QUERY_PARAMETER",
        "credential_parameter_name": "appid"
    }
)

weather_target_name = weather_target['name']
print("✅ OpenWeatherMap target added")
print(f"   Available tools: {weather_target_name}___getCurrentWeather, {weather_target_name}___getWeatherForecast")
# Out:
# 2026-02-10 09:33:40,359 - bedrock_agentcore.gateway - INFO - Creating credential provider
# 🌤️ Adding OpenWeatherMap (Weather)...
# 2026-02-10 09:33:41,673 - bedrock_agentcore.gateway - INFO - ✓ Added credential provider successfully (ARN: arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/WeatherSearch-ApiKey-1c07aeef)
# 2026-02-10 09:33:41,675 - bedrock_agentcore.gateway - INFO - Creating Target
# 2026-02-10 09:33:41,676 - bedrock_agentcore.gateway - INFO - {'gatewayIdentifier': 'travelmategateway-ufmin6tijj', 'name': 'WeatherSearch', 'targetConfiguration': {'mcp': {'openApiSchema': {'inlinePayload': '{"openapi": "3.0.0", "info": {"title": "OpenWeatherMap API", "version": "2.5", "description": "Weather forecasts and current conditions"}, "servers": [{"url": "https://api.openweathermap.org/data/2.5"}], "paths": {"/weather": {"get": {"summary": "Get current weather", "operationId": "getCurrentWeather", "description": "Get current weather data for a location", "parameters": [{"name": "q", "in": "query", "description": "City name (e.g., Rome, Florence)", "required": false, "schema": {"type": "string"}}, {"name": "lat", "in": "query", "description": "Latitude", "required": false, "schema": {"type": "number"}}, {"name": "lon", "in": "query", "description": "Longitude", "required": false, "schema": {"type": "number"}}, {"name": "units", "in": "query", "description": "Temperature units (standard, metric, imperial)", "required": false, "schema": {"type": "string", "default": "metric"}}], "responses": {"200": {"description": "Current weather data", "content": {"application/json": {"schema": {"type": "object", "properties": {"weather": {"type": "array", "items": {"type": "object", "properties": {"description": {"type": "string"}, "main": {"type": "string"}}}}, "main": {"type": "object", "properties": {"temp": {"type": "number"}, "feels_like": {"type": "number"}, "humidity": {"type": "integer"}}}, "name": {"type": "string"}}}}}}}}}, "/forecast": {"get": {"summary": "Get weather forecast", "operationId": "getWeatherForecast", "description": "Get 5 day weather forecast with 3-hour intervals", "parameters": [{"name": "q", "in": "query", "description": "City name", "required": false, "schema": {"type": "string"}}, {"name": "lat", "in": "query", "description": "Latitude", "required": false, "schema": {"type": "number"}}, {"name": "lon", "in": "query", "description": "Longitude", "required": false, "schema": {"type": "number"}}, {"name": "units", "in": "query", "description": "Units (metric, imperial)", "required": false, "schema": {"type": "string", "default": "metric"}}], "responses": {"200": {"description": "5-day forecast", "content": {"application/json": {"schema": {"type": "object", "properties": {"list": {"type": "array", "items": {"type": "object", "properties": {"dt_txt": {"type": "string"}, "main": {"type": "object", "properties": {"temp": {"type": "number"}}}, "weather": {"type": "array", "items": {"type": "object", "properties": {"description": {"type": "string"}}}}}}}}}}}}}}}}}'}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'API_KEY', 'credentialProvider': {'apiKeyCredentialProvider': {'providerArn': 'arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/WeatherSearch-ApiKey-1c07aeef', 'credentialLocation': 'QUERY_PARAMETER', 'credentialParameterName': 'appid'}}}]}
# ---------------------------------------------------------------------------
# ConflictException                         Traceback (most recent call last)
# Cell In[19], line 5
#       2 print("🌤️ Adding OpenWeatherMap (Weather)...")
#       4 weather_spec = specs["OpenWeatherMap (Weather)"]
# ----> 5 weather_target = client.create_mcp_gateway_target(
#       6     gateway=gateway,
#       7     name="WeatherSearch",
#       8     target_type="openApiSchema",
#       9     target_payload={
#      10         "inlinePayload": json.dumps(weather_spec)
#      11     },
#      12     credentials={
#      13         "api_key": api_keys["OPENWEATHERMAP_API_KEY"],
#      14         "credential_location": "QUERY_PARAMETER",
#      15         "credential_parameter_name": "appid"
#      16     }
#      17 )
#      19 weather_target_name = weather_target['name']
#      20 print("✅ OpenWeatherMap target added")
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\bedrock_agentcore_starter_toolkit\operations\gateway\client.py:164, in GatewayClient.create_mcp_gateway_target(self, gateway, name, target_type, target_payload, credentials)
#     162 self.logger.info(create_request)
#     163 self.logger.debug("Creating target with params: %s", json.dumps(create_request, indent=2))
# --> 164 target = self.client.create_gateway_target(**create_request)
#     165 self.logger.info("✓ Added target successfully (ID: %s)", target["targetId"])
#     166 self.logger.info("  Waiting for target to be ready...")
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\srinivas.susarapu\mastering-amazon-bedrock-agentcore\.venv\lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ConflictException: An error occurred (ConflictException) when calling the CreateGatewayTarget operation: A target with name 'WeatherSearch' already exists in this gateway

# %%
# Add ExchangeRate-API target (Currency)
print("💱 Adding ExchangeRate-API (Currency)...")

currency_spec = specs["ExchangeRate-API (Currency)"]
currency_target = client.create_mcp_gateway_target(
    gateway=gateway,
    name="ExchangeRate",
    target_type="openApiSchema",
    target_payload={
        "inlinePayload": json.dumps(currency_spec)
    },
    credentials={
        "api_key": api_keys["EXCHANGERATE_API_KEY"],
        "credential_location": "QUERY_PARAMETER",
        "credential_parameter_name": "api_key"
    }
)

currency_target_name = currency_target['name']
print("✅ ExchangeRate-API target added")
print(f"   Available tools: {currency_target_name}___getExchangeRates, {currency_target_name}___convertCurrency")
# Out:
# 2026-02-10 09:33:53,628 - bedrock_agentcore.gateway - INFO - Creating credential provider
# 💱 Adding ExchangeRate-API (Currency)...
# 2026-02-10 09:33:55,078 - bedrock_agentcore.gateway - INFO - ✓ Added credential provider successfully (ARN: arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/ExchangeRate-ApiKey-931dd12e)
# 2026-02-10 09:33:55,085 - bedrock_agentcore.gateway - INFO - Creating Target
# 2026-02-10 09:33:55,087 - bedrock_agentcore.gateway - INFO - {'gatewayIdentifier': 'travelmategateway-ufmin6tijj', 'name': 'ExchangeRate', 'targetConfiguration': {'mcp': {'openApiSchema': {'inlinePayload': '{"openapi": "3.0.0", "info": {"title": "ExchangeRate-API", "version": "6.0", "description": "Currency exchange rates"}, "servers": [{"url": "https://v6.exchangerate-api.com/v6"}], "paths": {"/{api_key}/latest/{base_currency}": {"get": {"summary": "Get latest exchange rates", "operationId": "getExchangeRates", "description": "Get latest exchange rates for a base currency", "parameters": [{"name": "api_key", "in": "path", "description": "Your API key", "required": true, "schema": {"type": "string"}}, {"name": "base_currency", "in": "path", "description": "Base currency code (e.g., USD, EUR)", "required": true, "schema": {"type": "string"}}], "responses": {"200": {"description": "Exchange rates", "content": {"application/json": {"schema": {"type": "object", "properties": {"result": {"type": "string"}, "base_code": {"type": "string"}, "conversion_rates": {"type": "object", "additionalProperties": {"type": "number"}}}}}}}}}}, "/{api_key}/pair/{from_currency}/{to_currency}": {"get": {"summary": "Convert between currencies", "operationId": "convertCurrency", "description": "Get conversion rate between two currencies", "parameters": [{"name": "api_key", "in": "path", "description": "Your API key", "required": true, "schema": {"type": "string"}}, {"name": "from_currency", "in": "path", "description": "Source currency code", "required": true, "schema": {"type": "string"}}, {"name": "to_currency", "in": "path", "description": "Target currency code", "required": true, "schema": {"type": "string"}}], "responses": {"200": {"description": "Conversion rate", "content": {"application/json": {"schema": {"type": "object", "properties": {"result": {"type": "string"}, "base_code": {"type": "string"}, "target_code": {"type": "string"}, "conversion_rate": {"type": "number"}}}}}}}}}}}'}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'API_KEY', 'credentialProvider': {'apiKeyCredentialProvider': {'providerArn': 'arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/ExchangeRate-ApiKey-931dd12e', 'credentialLocation': 'QUERY_PARAMETER', 'credentialParameterName': 'api_key'}}}]}
# 2026-02-10 09:33:55,617 - bedrock_agentcore.gateway - INFO - ✓ Added target successfully (ID: BKRE70NEZZ)
# 2026-02-10 09:33:55,621 - bedrock_agentcore.gateway - INFO -   Waiting for target to be ready...
# 2026-02-10 09:34:01,047 - bedrock_agentcore.gateway - INFO -
# ✅Target is ready
# ✅ ExchangeRate-API target added
#    Available tools: ExchangeRate___getExchangeRates, ExchangeRate___convertCurrency

# %% [markdown]
# ## Step 6: Test Gateway Tools

# %%
# Test weather API (most reliable for testing)
import requests

print("🧪 Testing Gateway Tools")
print("=" * 40)

# Get access token for testing
access_token = client.get_access_token_for_cognito({
    "client_id": cognito_result['client_info']['client_id'],
    "client_secret": cognito_result['client_info']['client_secret'],
    "scope": cognito_result['client_info']['scope'],
    "token_endpoint": cognito_result['client_info']['token_endpoint']
})

print(f"✅ Access token obtained: {access_token[:20]}...")

# Test gateway tool function
def test_gateway_tool(tool_name, arguments):
    """Test a gateway tool via MCP"""
    try:
        response = requests.post(
            f"{gateway['gatewayUrl']}/mcp",
            headers={
                "Authorization": f"Bearer {access_token}",
                "Content-Type": "application/json"
            },
            json={
                "method": "tools/call",
                "params": {
                    "name": tool_name,
                    "arguments": arguments
                }
            }
        )
        
        if response.status_code == 200:
            print(f"✅ {tool_name} - Success")
            result = response.json()
            print(f"   Response: {str(result)[:200]}...")
            return result
        else:
            print(f"❌ {tool_name} - Failed ({response.status_code})")
            print(f"   Error: {response.text[:200]}...")
            return None
    except Exception as e:
        print(f"❌ {tool_name} - Exception: {str(e)}")
        return None
# Out:
# 2026-02-10 09:39:58,433 - bedrock_agentcore.gateway - INFO - Fetching test token from Cognito...
# 2026-02-10 09:39:58,435 - bedrock_agentcore.gateway - INFO -   Attempting to connect to token endpoint: https://agentcore-c1478952.auth.us-east-1.amazoncognito.com/oauth2/token
# 🧪 Testing Gateway Tools
# ========================================
# 2026-02-10 09:40:02,632 - bedrock_agentcore.gateway - INFO - ✓ Got test token successfully
# ✅ Access token obtained: eyJraWQiOiJzZEhuUFlB...

# %%
# Test getCurrentWeather tool
def test_gateway_tool(tool_name, arguments):
    """Test a gateway tool via MCP"""
    try:
        response = requests.post(
            f"{gateway['gatewayUrl']}",
            headers={
                "Authorization": f"Bearer {access_token}",
                "Content-Type": "application/json"
            },
            json={
                "jsonrpc": "2.0",
                "id": f"test-{tool_name}",
                "method": "tools/call",
                "params": {
                    "name": tool_name,
                    "arguments": arguments
                }
            }
        )
        
        if response.status_code == 200:
            print(f"✅ {tool_name} - Success")
            result = response.json()
            print(f"   Response: {str(result)[:500]}...")
            return result
        else:
            print(f"❌ {tool_name} - Failed ({response.status_code})")
            print(f"   Error: {response.text[:200]}...")
            return None
    except Exception as e:
        print(f"❌ {tool_name} - Exception: {str(e)}")
        return None

# %%
import boto3

# Initialize the bedrock-agentcore-control client
agentcore_client = boto3.client('bedrock-agentcore-control', region_name='us-east-1')
secrets_client = boto3.client('secretsmanager', region_name='us-east-1')

def get_exchangerate_api_key():
    """Find and retrieve the ExchangeRate API key credential provider"""
    try:
        # Step 1: List all providers to find the ExchangeRate one
        print("🔍 Searching for ExchangeRate API key provider...")
        response = agentcore_client.list_api_key_credential_providers(maxResults=100)
        
        providers = response.get('credentialProviders', [])
        exchangerate_provider = None
        
        # Find the provider that starts with "ExchangeRate-ApiKey"
        for provider in providers:
            if provider['name'].startswith('ExchangeRate-ApiKey'):
                exchangerate_provider = provider
                break
        
        if not exchangerate_provider:
            print(f"❌ ExchangeRate API key provider not found")
            return None
        
        provider_name = exchangerate_provider['name']
        print(f"✅ Found provider: {provider_name}")
        
        # Step 2: Get the credential provider details
        provider_response = agentcore_client.get_api_key_credential_provider(name=provider_name)
        
        print(f"   ARN: {provider_response['credentialProviderArn']}")
        
        # Step 3: Extract the secret ARN
        secret_arn = provider_response['apiKeySecretArn']['secretArn']
        print(f"   Secret ARN: {secret_arn}")
        
        # Step 4: Retrieve the actual API key from Secrets Manager
        print(f"\n🔐 Retrieving API key from Secrets Manager...")
        secret_response = secrets_client.get_secret_value(SecretId=secret_arn)
        
        # The secret value could be a string or JSON
        if 'SecretString' in secret_response:
            secret_value = secret_response['SecretString']
            
            # Try to parse as JSON first
            try:
                secret_json = json.loads(secret_value)
                # If it's JSON, look for common API key field names
                api_key = secret_json.get('api_key') or secret_json.get('apiKey') or secret_json.get('key')
                if not api_key:
                    # If no standard field, return the whole JSON
                    api_key = secret_value
            except json.JSONDecodeError:
                # If not JSON, it's likely just the raw API key string
                api_key = secret_value
        else:
            # Binary secret
            api_key = secret_response['SecretBinary']
        
        print(f"✅ Successfully retrieved API key")
        print(f"\n🎉 ExchangeRate API Key: {api_key}")
        
        return api_key
        
    except Exception as e:
        print(f"❌ Error retrieving API key: {e}")
        return None

# %%
exchange_rate_apikey = json.loads(get_exchangerate_api_key())["api_key_value"]
# Out:
# 🔍 Searching for ExchangeRate API key provider...
# ✅ Found provider: ExchangeRate-ApiKey-931dd12e
#    ARN: arn:aws:bedrock-agentcore:us-east-1:790402872574:token-vault/default/apikeycredentialprovider/ExchangeRate-ApiKey-931dd12e
#    Secret ARN: arn:aws:secretsmanager:us-east-1:790402872574:secret:bedrock-agentcore-identity!default/apikey/ExchangeRate-ApiKey-931dd12e-YqfCCQ
#
# 🔐 Retrieving API key from Secrets Manager...
# ✅ Successfully retrieved API key
#
# 🎉 ExchangeRate API Key: {"api_key_value":"1876e28e1d152b5b155ec14e"}

# %%
# Test weather for Rome
print("\n🌤️ Testing Weather API:")
weather_result = test_gateway_tool(f"{weather_target_name}___getCurrentWeather", {
    #"q": "Rome,IT",
    "q": "Bangalore,IN",
    "units": "metric"
})
# Out:
# 🌤️ Testing Weather API:
# ✅ WeatherSearch___getCurrentWeather - Success
#    Response: {'jsonrpc': '2.0', 'id': 'test-WeatherSearch___getCurrentWeather', 'result': {'isError': False, 'content': [{'type': 'text', 'text': '{"coord":{"lon":77.6033,"lat":12.9762},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":21.35,"feels_like":21.19,"temp_min":19.9,"temp_max":23.05,"pressure":1017,"humidity":63,"sea_level":1017,"grnd_level":919},"visibility":6000,"wind":{"speed":5.81,"deg":96,"gust":15.65},"clouds":{"all":98},"dt":...

# %%
# Test currency conversion
print("\n💱 Testing Currency API:")
currency_result = test_gateway_tool(f"{currency_target_name}___convertCurrency", {
    "api_key": exchange_rate_apikey,
    "from_currency": "USD",
    "to_currency": "EUR"
})
# Out:
# 💱 Testing Currency API:
# ✅ ExchangeRate___convertCurrency - Success
#    Response: {'jsonrpc': '2.0', 'id': 'test-ExchangeRate___convertCurrency', 'result': {'isError': False, 'content': [{'type': 'text', 'text': '{"result":"success","documentation":"https://www.exchangerate-api.com/docs","terms_of_use":"https://www.exchangerate-api.com/terms","time_last_update_unix":1770681602,"time_last_update_utc":"Tue, 10 Feb 2026 00:00:02 +0000","time_next_update_unix":1770768002,"time_next_update_utc":"Wed, 11 Feb 2026 00:00:02 +0000","base_code":"USD","target_code":"EUR","conversion_rat...

# %%
# Test flight search (may have limited results with free tier)
print("\n✈️ Testing Flight API:")
flight_result = test_gateway_tool(f"{aviationstack_target_name}___getFlights", {
    "dep_iata": "JFK",
    "arr_iata": "FCO",
    "limit": 5
})
# Out:
# ✈️ Testing Flight API:
# ✅ FlightSearch___getFlights - Success
#    Response: {'jsonrpc': '2.0', 'id': 'test-FlightSearch___getFlights', 'result': {'isError': False, 'content': [{'type': 'text', 'text': '{"pagination":{"limit":5,"offset":0,"count":5,"total":8},"data":[{"flight_date":"2026-02-09","flight_status":"active","departure":{"airport":"John F Kennedy International","timezone":"America/New_York","iata":"JFK","icao":"KJFK","terminal":"1","gate":"8","delay":null,"scheduled":"2026-02-09T21:15:00+00:00","estimated":"2026-02-09T21:15:00+00:00","actual":"2026-02-09T21:52...

# %% [markdown]
# ## Step 7: Save Gateway Information

# %%
# Save gateway information for use in subsequent notebooks
gateway_info = {
    "gateway_name": GATEWAY_NAME,
    "gateway_id": gateway['gatewayId'],
    "mcp_endpoint": gateway['gatewayUrl'],
    "region": REGION,
    "oauth_client_id": cognito_result['client_info']['client_id'],
    "oauth_client_secret": cognito_result['client_info']['client_secret'],
    "oauth_scope": cognito_result['client_info']['scope'],
    "available_tools": [
        f"{aviationstack_target_name}___getFlights",
        f"{weather_target_name}___getCurrentWeather",
        f"{weather_target_name}___getWeatherForecast",
        f"{currency_target_name}___getExchangeRates",
        f"{currency_target_name}___convertCurrency"
    ]
}

# Save to file for next notebooks
with open('environments/gateway_info.json', 'w') as f:
    json.dump(gateway_info, f, indent=2)

print("💾 Gateway information saved to environments/gateway_info.json")
print("\n📋 Gateway Summary:")
print(f"  Gateway ID: {gateway_info['gateway_id']}")
print(f"  MCP Endpoint: {gateway_info['mcp_endpoint']}")
print(f"  Available Tools: {len(gateway_info['available_tools'])}")
for tool in gateway_info['available_tools']:
    print(f"    - {tool}")
# Out:
# 💾 Gateway information saved to environments/gateway_info.json
#
# 📋 Gateway Summary:
#   Gateway ID: travelmategateway-ufmin6tijj
#   MCP Endpoint: https://travelmategateway-ufmin6tijj.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp
#   Available Tools: 5
#     - FlightSearch___getFlights
#     - WeatherSearch___getCurrentWeather
#     - WeatherSearch___getWeatherForecast
#     - ExchangeRate___getExchangeRates
#     - ExchangeRate___convertCurrency

# %% [markdown]
# ## Step 8: Integration Summary

# %%
# Display integration summary
print("🎉 GATEWAY INTEGRATION COMPLETE!")
print("=" * 50)
print(f"\n✅ Created Gateway: {GATEWAY_NAME}")
print(f"✅ Configured OAuth with Cognito")
print(f"✅ Added 4 API integrations:")
print(f"   • Aviationstack (Flight search)")
print(f"   • Hotelbeds (Hotel search)")
print(f"   • OpenWeatherMap (Weather data)")
print(f"   • ExchangeRate-API (Currency conversion)")
print(f"\n🔧 Available MCP Tools: {len(gateway_info['available_tools'])}")
print(f"\n🌐 MCP Endpoint: {gateway_info['mcp_endpoint']}")
print(f"\n🔐 OAuth Client ID: {gateway_info['oauth_client_id']}")

print("\n➡️ Next Steps:")
print("   1. Integrate Gateway tools into travel agent (Notebook 04)")
print("   2. Add memory for user preferences")
print("   3. Implement identity management")
print("   4. Add code interpreter and browser tools")
# Out:
# 🎉 GATEWAY INTEGRATION COMPLETE!
# ==================================================
#
# ✅ Created Gateway: TravelMateGateway
# ✅ Configured OAuth with Cognito
# ✅ Added 4 API integrations:
#    • Aviationstack (Flight search)
#    • Hotelbeds (Hotel search)
#    • OpenWeatherMap (Weather data)
#    • ExchangeRate-API (Currency conversion)
#
# 🔧 Available MCP Tools: 5
#
# 🌐 MCP Endpoint: https://travelmategateway-ufmin6tijj.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp
#
# 🔐 OAuth Client ID: 42g73g97d8cf2us2ebuf3hhu0k
#
# ➡️ Next Steps:
#    1. Integrate Gateway tools into travel agent (Notebook 04)
#    2. Add memory for user preferences
#    3. Implement identity management
#    4. Add code interpreter and browser tools

# %% [markdown]
# ## Next Steps
#
# ✅ **Completed in this notebook:**
# - AgentCore Gateway creation with OAuth
# - OpenAPI 3.0 specifications for all 4 APIs
# - External API integrations (flights, hotels, weather, currency)
# - MCP tool calling and testing
# - Gateway information persistence
#
# ➡️ **Next: Notebook 04 - Memory Implementation**
# - Set up AgentCore Memory for user preferences
# - Implement conversation context management
# - Add personalization based on user history
# - Integrate memory with travel agent
